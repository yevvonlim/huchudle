# %%
from HuchuDataset import HuchuDataset

dataset = HuchuDataset("/workspace/austin/huchuset/huchudle-train-lm-caption.json",
                        "/workspace/austin/huchuset/cropped_image")

# %%
len(dataset)
# Out:
# 222221

# %%
img, draw_img, caption = dataset[1]

# %%
from IPython.display import display
from PIL import Image

Image.fromarray(((img.permute(1, 2, 0).numpy()+1)/2*255).astype('uint8'))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>
