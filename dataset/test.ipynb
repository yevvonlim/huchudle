# %%
from HuchuDataset import HuchuDataset

dataset = HuchuDataset("/workspace/austin/spandjp/img/landmark.json",
                        "/workspace/austin/spandjp/img/cropped_img", istrain=False)

# %%
len(dataset)
# Out:
# 5

# %%
img, draw_img, caption = dataset[0]
from IPython.display import display
from PIL import Image

Image.fromarray(((img.permute(1, 2, 0).numpy()+1)/2*255).astype('uint8'))
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>
